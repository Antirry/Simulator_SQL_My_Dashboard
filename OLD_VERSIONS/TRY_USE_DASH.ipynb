# %%
# %run EXPRESS_ГЛАВА_2_1_Метрики_и_графики_ЗАДАНИЯ.ipynb import Total_peoples, New_peoples, New_Peoples_Change, Total_peoples_growth, Active_peoples, Peoples_share, New_Peoples_Share, Order_related_indicators, Dynamics_of_users_and_couriers_share, orders_users_per_courier, average_delivery_time, Indicator_dynamics_orders

# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.

from dash import Dash, html, dcc
import dash_bootstrap_components as dbc

app = Dash(__name__)

app.layout = html.Div(
    style={'backgroundColor': 'black', 'color': 'white', 'fontFamily': 'Quango, sans-serif'},
    children=[
        html.H2(children='Что происходит? (Общая ситуация по заказам) (Задания)'),
        html.H3(children='''
            Это - Глава 2 - Урок 1 - Метрики, задания
        '''),
        dbc.Row([
            dbc.Col(dcc.Graph(
                id='Total_peoples',
                figure=Total_peoples.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='New_peoples',
                figure=New_peoples.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='New_Peoples_Change',
                figure=New_Peoples_Change.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4)
        ]),

        dbc.Row([
            dbc.Col(dcc.Graph(
                id='Total_peoples_growth',
                figure=Total_peoples_growth.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='Active_peoples',
                figure=Active_peoples.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='Peoples_share',
                figure=Peoples_share.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4)
        ]),

        dbc.Row([
            dbc.Col(dcc.Graph(
                id='New_Peoples_Share',
                figure=New_Peoples_Share.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='Order_related_indicators',
                figure=Order_related_indicators.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='Dynamics_of_users_and_couriers_share',
                figure=Dynamics_of_users_and_couriers_share.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4)
        ]),
        
        dbc.Row([
            dbc.Col(dcc.Graph(
                id='orders_users_per_courier',
                figure=orders_users_per_courier.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='average_delivery_time',
                figure=average_delivery_time.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4),
            dbc.Col(dcc.Graph(
                id='Indicator_dynamics_orders',
                figure=Indicator_dynamics_orders.update_layout(
                    {"plot_bgcolor": "rgba(0, 0, 0, 0)", "paper_bgcolor": "rgba(0, 0, 0, 0)"}
                )
            ), width=4)
        ])
    ]
)

if __name__ == '__main__':
    app.run(debug=True)
